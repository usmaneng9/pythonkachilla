# %% [markdown]
# # Participant
#
# Name = "Muhammad Usman"
#
# Title = "Engr"
#
# email = "usmaneng9@gmail.com"
#
# Whatsapp = "00923471299571"

# %%
print("This is my first object.")
# Out:
# This is my first object.
